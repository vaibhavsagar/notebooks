-- %%
{-# LANGUAGE QuasiQuotes #-}

import IHaskell.Display.Graphviz
import Data.String.Here

-- %%
dot [here|
    digraph {
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        2 [label="2,2"]
        1 -> 2 [color=red]
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 2, 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        2 [label="2,2"]
        3 [label="3,3"]
        1 -> 2
        2 -> 3 [color=red]
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 3, 2, 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        2 [label="2,2"]
        3 [label="3,1"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back, color=red]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 3, 2, 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        2 [label="2,1"]
        3 [label="3,1"]
        1 -> 2
        2 -> 3 [color=red]
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 3, 2, 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1"]
        2 [label="2,1"]
        3 [label="3,1"]
        1 -> 2 [color=red]
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 3, 2, 1 ]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 3, 2, 1 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back,color=red]
        4 -> 3
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3 [color=red]
        4 -> 5
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,5"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5 [color=red]
        5 -> 4
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 [color=red]
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 [color=red]
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back,color=red]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        7 [label="7,7"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back]
        6 -> 7 [color=red]
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 7, 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        7 [label="7,6"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6 [color=red]
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 7, 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        7 [label="7,6"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6 [color=red]
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 7, 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6"]
        7 [label="7,6"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back]
        6 -> 7 [color=red]
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 7, 6, 5, 4 ]
output=[[3,2,1]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 5, 4 ]
output=[[3,2,1],[7,6]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6 [color=red]
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 5, 4 ]
output=[[3,2,1],[7,6]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4"]
        5 [label="5,4"]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5 [color=red]
        5 -> 4 
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 5, 4 ]
output=[[3,2,1],[7,6]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4",style=filled]
        5 [label="5,4",style=filled]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ ]
output=[[3,2,1],[7,6],[5,4]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4",style=filled]
        5 [label="5,4",style=filled]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        8 [label="8,8"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 8 ]
output=[[3,2,1],[7,6],[5,4]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4",style=filled]
        5 [label="5,4",style=filled]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        8 [label="8,8"]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8 [color=red]
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 8 ]
output=[[3,2,1],[7,6],[5,4]]

-- %%
(dot [here| 
    digraph {
        node[label=""]
        1 [label="1,1",style=filled]
        2 [label="2,1",style=filled]
        3 [label="3,1",style=filled]
        4 [label="4,4",style=filled]
        5 [label="5,4",style=filled]
        6 [label="6,6",style=filled]
        7 [label="7,6",style=filled]
        8 [label="8,8",style=filled]
        1 -> 2
        2 -> 3
        1 -> 3 [dir=back]
        2 -> 4 [dir=back]
        4 -> 3
        4 -> 5
        5 -> 4 
        5 -> 6
        3 -> 6 [dir=back]
        6 -> 7
        7 -> 6
        5 -> 8 [dir=back]
        8 -> 7
        8 -> 8
        {rank=same; 1 3 6 7}
        {rank=same; 2 4 5 8}
    }
|])

stack = [ 8 ]
output=[[3,2,1],[7,6],[5,4],[8]]

-- %%
dot [here|
    digraph {
        A -> { B C }
        B -> E
        C -> E
        C -> D [dir=back]
        D -> E
    {rank=same; B C D}
    }
|]

-- %%
dot [here|
    digraph {
        A -> { B C }
        B -> E
        C -> E
        C -> D [dir=back]
        D -> E [dir=back,color=red]
    {rank=same; B C D}
    }
|]
