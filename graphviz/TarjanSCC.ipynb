-- %%
{-# LANGUAGE OverloadedStrings #-}
{-# LANGUAGE QuasiQuotes #-}

import IHaskell.Display.Graphviz
import Data.String.Here

-- %%
dot TopToBottom [here|
    digraph {
      1 -> 2
      2 -> 3
      1 -> 3 [dir=back]
      2 -> 4 [dir=back]
      4 -> 3
      4 -> 5
      5 -> 4
      5 -> 6
      3 -> 6 [dir=back]
      6 -> 7
      7 -> 6
      5 -> 8 [dir=back]
      8 -> 7
      8 -> 8
      {rank=same; 1 3 6 7}
      {rank=same; 2 4 5 8}
    }
|]
